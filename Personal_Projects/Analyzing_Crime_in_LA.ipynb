# %%
# Re-run this cell
# Import required libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
crimes = pd.read_csv("crimes.csv", parse_dates=["Date Rptd", "DATE OCC"], dtype={"TIME OCC": str})
crimes.head()
# Out:
#        DR_NO  Date Rptd   DATE OCC TIME OCC    AREA NAME        Crm Cd Desc  \
# 0  220314085 2022-07-22 2020-05-12     1110    Southwest  THEFT OF IDENTITY
# 1  222013040 2022-08-06 2020-06-04     1620      Olympic  THEFT OF IDENTITY
# 2  220614831 2022-08-18 2020-08-17     1200    Hollywood  THEFT OF IDENTITY
# 3  231207725 2023-02-27 2020-01-27     0635  77th Street  THEFT OF IDENTITY
# 4  220213256 2022-07-14 2020-07-14     0900      Rampart  THEFT OF IDENTITY
#
#    Vict Age Vict Sex Vict Descent Weapon Desc  Status Desc  \
# 0        27        F            B         NaN  Invest Cont
# 1        60        M            H         NaN  Invest Cont
# 2        28        M            H         NaN  Invest Cont
# 3        37        M            H         NaN  Invest Cont
# 4        79        M            B         NaN  Invest Cont
#
#                                   LOCATION
# 0  2500 S  SYCAMORE                     AV
# 1  3300    SAN MARINO                   ST
# 2                        1900    TRANSIENT
# 3  6200    4TH                          AV
# 4  1200 W  7TH                          ST

# %%
import datetime
from datetime import datetime 
hours = []
for time in crimes['TIME OCC']:
    datetime_obj = datetime.strptime(time, "%H%M")
    hour = datetime_obj.time().hour
    hours.append(hour)

# %%
crimes.insert(2, "Time_Hour", hours)

# %%
crimes.head()
# Out:
#        DR_NO  Date Rptd  Time_Hour   DATE OCC TIME OCC    AREA NAME  \
# 0  220314085 2022-07-22         11 2020-05-12     1110    Southwest
# 1  222013040 2022-08-06         16 2020-06-04     1620      Olympic
# 2  220614831 2022-08-18         12 2020-08-17     1200    Hollywood
# 3  231207725 2023-02-27          6 2020-01-27     0635  77th Street
# 4  220213256 2022-07-14          9 2020-07-14     0900      Rampart
#
#          Crm Cd Desc  Vict Age Vict Sex Vict Descent Weapon Desc  Status Desc  \
# 0  THEFT OF IDENTITY        27        F            B         NaN  Invest Cont
# 1  THEFT OF IDENTITY        60        M            H         NaN  Invest Cont
# 2  THEFT OF IDENTITY        28        M            H         NaN  Invest Cont
# 3  THEFT OF IDENTITY        37        M            H         NaN  Invest Cont
# 4  THEFT OF IDENTITY        79        M            B         NaN  Invest Cont
#
#                                   LOCATION
# 0  2500 S  SYCAMORE                     AV
# 1  3300    SAN MARINO                   ST
# 2                        1900    TRANSIENT
# 3  6200    4TH                          AV
# 4  1200 W  7TH                          ST

# %%
peak_crime_hour = 0
count = 0
for hour in range (max(hours)+1):
    a = hours.count(hour)
    if(count<a):
        count = a
        peak_crime_hour = hour
    hour = hour+1
peak_crime_hour
# Out:
# 12
